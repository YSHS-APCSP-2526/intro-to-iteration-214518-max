# %% [markdown]
# <a href="https://colab.research.google.com/github/YSHS-APCSP-2526/intro-to-iteration-214518-max/blob/main/Intro_to_Iteration_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # For Loops: Read
#
# A lot of times it is useful to be able to repeat the same line of code multiple times. Repeating a process is called <b> iteration </b>.
#
# A common way to iterate in python is by using for loops. They have the structure seen below.
#
# ```python
# for i in list:
#   print(i)
# ```
# Run the code below to see a for loop in action.

# %%
DaysOfWeek = ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']

for i in DaysOfWeek:
  print(i)
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %% [markdown]
# We can spice up the for loop a little bit...

# %%
DaysOfWeek = ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']

for i in DaysOfWeek:
  if i =="Friday":
    print("Today is " + i+ "!!!!!")
  else:
      print("Today is " + i +"!")
# Out:
# Today is Monday!
# Today is Tuesday!
# Today is Wednesday!
# Today is Thursday!
# Today is Friday!!!!!
# Today is Saturday!
# Today is Sunday!

# %% [markdown]
# This can be useful for repeated mathematical operations! Consider the code below.

# %%
numbers = [2,10,21,40]
for i in numbers:
  print(i*2)
# Out:
# -36
# -20
# 2
# 40

# %% [markdown]
# # Your First For Loop: Do
# Make a for loop in the code block below that welcomes each student individually. "Welcome Bob!, "Welcome Tom!"

# %%
Students =['Mason',"Deborah","Mr.Flannelly","Kuba","AJ","Oreo","Ava","Lyla","Atticus",'Catlin',"Angle","Ethan"]
for i in Students:
  print("Hello, how is your day " + i)
# Out:
# Hello, how is your day Mason
# Hello, how is your day Deborah
# Hello, how is your day Mr.Flannelly
# Hello, how is your day Kuba
# Hello, how is your day AJ
# Hello, how is your day Oreo
# Hello, how is your day Ava
# Hello, how is your day Lyla
# Hello, how is your day Atticus
# Hello, how is your day Catlin
# Hello, how is your day Angle
# Hello, how is your day Ethan

# %% [markdown]
# #Control within the For Loop: Read
# You can include as much conditional logic as you want within in a for loop which allows you to perform different logic based on the input. Look at the below code that takes a list of ages as an input and outputs whether they can vote or not.*italicized text*

# %%
ages = [12,19,14,18,45,1,17,25]
for i in ages:
  if i >= 21:
    print("You Can Vote! Your age of ", i ," is greater than or equal to the voting age!")

  else:
    print("You can not yet vote! Your age of ",i ," is less than the voting age!" )
# Out:
# You can not yet vote! Your age of  12  is less than the voting age!
# You can not yet vote! Your age of  19  is less than the voting age!
# You can not yet vote! Your age of  14  is less than the voting age!
# You can not yet vote! Your age of  18  is less than the voting age!
# You Can Vote! Your age of  45  is greater than or equal to the voting age!
# You can not yet vote! Your age of  1  is less than the voting age!
# You can not yet vote! Your age of  17  is less than the voting age!
# You Can Vote! Your age of  25  is greater than or equal to the voting age!

# %% [markdown]
# #Control within the For Loop: Do
# Let's go back to the earlier example of welcoming individuals into the class. Keep the same for loop as before, but when you get to your name print a blank space (you can not welcome yourself to class).

# %%
Students =['Lyla','MASON','Cam','Nicholas','Jinhang','Jahiid','Oumou','Sasha','Deicis','Marquelle','Malcom','Yasir','Saw','Semhal','Zyra','Jeremy','Shamier','Alyssa','Dykembe','Imani','Maurice','Kadijah','Shakirah','Adam','Cody','Alex','Francess','Megan']

for i in Students:
  if i == "MASON":
    print(i)
  else:
    print("Hello, how is your day going "+ i +"!")
# Out:
# Hello, how is your day going Lyla!
# MASON
# Hello, how is your day going Cam!
# Hello, how is your day going Nicholas!
# Hello, how is your day going Jinhang!
# Hello, how is your day going Jahiid!
# Hello, how is your day going Oumou!
# Hello, how is your day going Sasha!
# Hello, how is your day going Deicis!
# Hello, how is your day going Marquelle!
# Hello, how is your day going Malcom!
# Hello, how is your day going Yasir!
# Hello, how is your day going Saw!
# Hello, how is your day going Semhal!
# Hello, how is your day going Zyra!
# Hello, how is your day going Jeremy!
# Hello, how is your day going Shamier!
# Hello, how is your day going Alyssa!
# Hello, how is your day going Dykembe!
# Hello, how is your day going Imani!
# Hello, how is your day going Maurice!
# Hello, how is your day going Kadijah!
# Hello, how is your day going Shakirah!
# Hello, how is your day going Adam!
# Hello, how is your day going Cody!
# Hello, how is your day going Alex!
# Hello, how is your day going Francess!
# Hello, how is your day going Megan!

# %% [markdown]
# # Highest Number in List Function: Do
# Create a function called HighNum() that takes 1 input numberlist and outputs the highest value in the number list. The number list is not presorted and the highest value number could be anywhere in the list. Some structural hints can be found below.
#
# 1. Define the function with 1 input
# 2. Make the first number in numberlist the starting maxnumber.
# ``` python
# maxnumber = numberlist[0]
# ```
# 3. Iterate through numberlist and if the number is greater than maxnumber redefine maxnumber as that number
# 4. After the code is done iterating through numberlist print maxnumber.

# %%
#Insert HighNum() function code here.
for i is numberlist

#test numberlist - your code should output 4000. You can change (modify,expand,contract) numberlist and your function should still work.
numberlist = [0,4000,-100, 400,3000]

def hughestnumb(numberlist)
  maxNumber=numberlist[0]
  for i in numberlist:
    if i > maxNumber

# %% [markdown]
# #Create your own for loop: Do
#
# In the code cell below create your own for loop. It must include
# 1. a for loop
# 2. a conditional statement
#
# besides that sky is the limit. Below your for loop briefly explain what it does.

# %%
#Insert your own for loop here

# %% [markdown]
# #Explain your for loop here.
